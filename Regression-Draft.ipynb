# %% [markdown]
# # Regression Research for Dynamics

# %% [markdown]
# # Target & Intro

# %% [markdown]
# A) write out a precise research question or questions - see my **previous notes for suggestions** here.
#
# B) set up and run the **regression analysis**, and then interpreting the results.
#
# After that, in August or before, you will need to:
#
# 1/ Assemble the dissertation itself from the component parts you already have in the Jupiter notebook and elsewhere. If you have time before we meet, try making an **outline** - basically sections with a note of what content goes in where. This will help you identify any gaps.
#
# 2/ Go back to the literature review - at the moment you are working from just a few references. You will need to expand that to more like **20-30** for this part of the dissertation to do well.
#
# ---
#
# Q1/ time series for entry rates - from the results in your EDA, it looks like data is pretty sparse even in your biggest clusters before the late 1970s. For the whole UK, a 20-year time series feels sensible, say 1998-2018. As you suggest, in the dissertation you will want to justify this with references to the cluster literature: try looking for studies on cluster evolution.
#
# ~Q1/进入率的时间序列——从你的 EDA 中的结果来看，即使在 1970 年代后期之前最大的集群中，数据看起来也非常稀少。 对于整个英国来说，20 年的时间序列是合理的，比如 1998-2018。 正如您所建议的，在论文中，您需要参考集群文献来证明这一点：尝试寻找关于集群演化的研究。~
#
# Q2/ Entry vs exit/churn - as we discussed, you should write a couple of sentences in the dissertation explaining that because most tech firms in your data are still active, exit rates are very low and churn rates are very similar to entry rates. Thus in your analysis you concentrate on entry rates. You should also give an example, e.g. for London or for the Uk average.
#
# ~Q2/进入与退出/流失——正如我们所讨论的，你应该在论文中写几句话来解释，因为你数据中的大多数科技公司仍然活跃，退出率非常低，流失率与进入率非常相似。 因此，在您的分析中，您专注于进入率。 您还应该举一个例子，例如 伦敦或英国平均水平。~
#
# Q3/ Entry rate definition - there is no obvious right answer here. If you are focused on dynamics *within* a tech cluster, I think it makes sense to define it for cluster i, year t, as new tech firms_it / all tech firms _it. If you are focused on the wider importance of tech clusters, you could define it as ew tech firms_it / all firms _it. Think about your chosen research questions(s) as a guide here.
#
# ~Q3/进入率定义——这里没有明显的正确答案。 如果您专注于技术集群*内*的动态，我认为将其定义为第 t 年集群 i 为新科技公司_it / 所有科技公司 _it 是有意义的。 如果您关注技术集群的更广泛重要性，您可以将其定义为新科技公司_it / 所有公司_it。考虑您选择的研究问题作为此处的指南。~
#
# ---
#
# Q4a/ **Regressions** - I've re-written them as OLS estimations below, for cluster i, year t, lag n, error e or u. Coefficients are b1, ... bj in (1) and c1, ... cj in (2):
#
# Q4a/ 回归 - 我已经将它们重写为下面的 OLS 估计，对于集群 i、t 年、滞后 n、错误 e 或 u。 系数是 (1) 中的 b1, ... bj 和 (2) 中的 c1, ... cj：
#
# Dynamics_variable_it = a1 + b2#firms_it-n + b3industry mix_it-n + Xb_it-n + location_i + year_t + e_it (1)
#
# - $ Dynamics\ Variable_{i,t} = a_1 + b_2 \times firms_{i,(t-n)} + b_3 \times industry\ mix_{i,(t-n)} + b_{X,i,(t-n)} + location_i + year_t + e_{i,t} $ (1)
#
# - $ Entry\ Rate_{i,t} = a_1 + b_2 \times firms_{i,(t-n)} + b_3 \times industry\ mix_{i,(t-n)} + b_{X,i,(t-n)} + location_i + year_t + e_{i,t} $ (1a)
#
# - $ Exit\ Rate_{i,t} = a_1 + b_2 \times firms_{i,(t-n)} + b_3 \times industry\ mix_{i,(t-n)} + b_{X,i,(t-n)} + location_i + year_t + e_{i,t} $ (1b)
#
# Firm_performance_it = c1 + c2#firms_it-n + c3dynamics_it-n + c4industry mix_it-n + Xc_it-n + location_i + year_t + u_it (2)
#
# - $ Firm\ Performance_{i,t} = c_1 + c_2 \times firms_{i,(t-n)} + c_3 \times dynamics_{i,(t-n)} + c_{X,i,(t-n)} + location_i + year_t + u_{i,t} $ (2)
#
# Remember that X is a vector of controls - use the lit review to think about what set of variables you would include here. Typically people include
# e.g. population density, share of graduates.
#
# Start by estimating in OLS with standard errors clustered on TTWA. Then think about more functionally correct estimators - e.g. geographically weighted regression.
#
# 请记住，X 是一个控件向量 - 使用点燃的评论来考虑您将在此处包含哪些变量集。 通常人们包括
# 例如 人口密度，毕业生比例。
#
# 首先在 OLS 中进行估计，标准误差聚集在 TTWA 上。 然后考虑更多功能正确的估计器 - 例如 地理加权回归。
#
# Q4b/ industry mix variable - how you build this depends on how you build the entry rate variable. If entry rate is defined in terms of all firms, then industry mix can be share of tech firms / all firms; the LQ of tech firms, or a Herfindahl Index of all industries. If entry rate is defined in terms of tech firms only, then industry mix should probably be a Herfindahl index of tech industry SICs [i.e. how diverse is the tech sector, is it dominated by e.g. software or IT consulting?]
#
# Q4b/行业组合变量——你如何构建它取决于你如何构建进入率变量。 如果进入率是根据所有公司来定义的，那么行业组合可以是科技公司/所有公司的份额； 科技公司的 LQ，或所有行业的赫芬达尔指数。 如果仅根据科技公司定义进入率，那么行业组合可能应该是科技行业 SIC 的赫芬达尔指数 [即 科技行业有多多样化，它是否由例如 软件或 IT 咨询？]
#
# 科技公司在科技集群里的进入率应该就是 `科技公司进入率 = 当地当年进入公司 / 当地当年所有科技公司 * 100%`
#
# Other things:
#
# * If you don't plan to measure clusters using data-driven methods like DB-Scan, you will need to justify this decision in the dissertation, especially as some tech clusters are likely to be smaller than TTWAs in practice. You could look at literature on TTWAs to argue that they are a good representation of local economies; you could also argue that limitations in OC address data mean it's sensible to aggregate firms to TTWA level (again, you will need references to back that up).
#
# * ~如果您不打算使用 DB-Scan 等数据驱动方法来衡量集群，则需要在论文中证明这一决定的合理性，特别是因为某些技术集群在实践中可能小于 TTWA。 您可以查看有关 TTWA 的文献，认为它们是当地经济的良好代表； 您还可以争辩说，OC 地址数据的限制意味着将公司聚合到 TTWA 级别是明智的（同样，您需要参考来支持这一点）。~
#
# 去找文献！

# %% [markdown]
# # Regression Research

# %% [markdown]
# ## Read Data

# %%
import pandas as pd
import sys
PATH = sys.path[0]

df = pd.read_csv(PATH + "/Dataset/fame_OC_tech_firm.csv",low_memory=False)
df = df.drop({"Unnamed: 0","Unnamed: 0.1","Unnamed: 0.1.1","is_tech"},axis = 1)

# preprocess the data
# drop the null value record in birth year and ttwa(travel to work area) columns
df = df.dropna(subset = {"birth_year","ttwa"})

df.head()
# Out:
#      registered_number incorporation_date dissolution_date  \
# 1691          SC586896         2018-01-26              NaN
# 1692          SC288343         2005-08-02              NaN
# 1693          SC108323         1987-12-17              NaN
# 1695          SC123734         1990-03-15              NaN
# 1696          SC110389         1988-04-12              NaN
#
#       latest_accounts_cash  latest_accounts_assets  \
# 1691                   NaN                     NaN
# 1692              431262.0               1751549.0
# 1693                   NaN                100180.0
# 1695                   NaN                     NaN
# 1696                   NaN                     NaN
#
#       latest_accounts_liabilities  year_obs  sic_year    sic4  change_sic  \
# 1691                          NaN      2018    2007.0  7112.0         0.0
# 1692                     407041.0      2013    2007.0  2899.0         0.0
# 1693                          NaN      2018    2007.0  7311.0         0.0
# 1695                          NaN      2018    2007.0  7112.0         0.0
# 1696                          NaN      2018    2007.0  3099.0         0.0
#
#       ...      pcd2      pcds        cty       laua       ctry        rgn  \
# 1691  ...  AB10 1AU  AB10 1AU  S99999999  S12000033  S92000003  S99999999
# 1692  ...  AB10 1DQ  AB10 1DQ  S99999999  S12000033  S92000003  S99999999
# 1693  ...  AB10 1DQ  AB10 1DQ  S99999999  S12000033  S92000003  S99999999
# 1695  ...  AB10 1DQ  AB10 1DQ  S99999999  S12000033  S92000003  S99999999
# 1696  ...  AB10 1DQ  AB10 1DQ  S99999999  S12000033  S92000003  S99999999
#
#            ttwa        pct       lep1       lep2
# 1691  S22000047  S03000012  S99999999  S99999999
# 1692  S22000047  S03000012  S99999999  S99999999
# 1693  S22000047  S03000012  S99999999  S99999999
# 1695  S22000047  S03000012  S99999999  S99999999
# 1696  S22000047  S03000012  S99999999  S99999999
#
# [5 rows x 64 columns]

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# Get the top 10 ttwas which have the most number of firms

# %%
# Generate the top 10 tech clusters table based on the ttwa
top_10_ttwa = df.ttwa.value_counts().head(10)
top_10_ttwa = pd.DataFrame(top_10_ttwa).reset_index()
top_10_ttwa.columns = ["ttwa_code","counts"]

df_ttwa = pd.read_csv(PATH + "/Dataset/ttwa.csv")
df_ttwa = pd.merge(top_10_ttwa, df_ttwa[["code","name"]], left_on="ttwa_code",right_on="code")
df_ttwa_10 = df_ttwa[["ttwa_code", "name","counts"]]
df_ttwa_10.style
# Out:
# <style  type="text/css" >
# </style><table id="T_ba9fa408_eb07_11eb_9506_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ttwa_code</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >counts</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ba9fa408_eb07_11eb_9506_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row0_col0" class="data row0 col0" >E30000234</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row0_col1" class="data row0 col1" >London</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row0_col2" class="data row0 col2" >119008</td>
#             </tr>
#             <tr>
#                         <th id="T_ba9fa408_eb07_11eb_9506_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row1_col0" class="data row1 col0" >E30000239</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row1_col1" class="data row1 col1" >Manchester</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row1_col2" class="data row1 col2" >18273</td>
#             </tr>
#             <tr>
#                         <th id="T_ba9fa408_eb07_11eb_9506_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row2_col0" class="data row2 col0" >E30000266</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row2_col1" class="data row2 col1" >Slough and Heathrow</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row2_col2" class="data row2 col2" >17367</td>
#             </tr>
#             <tr>
#                         <th id="T_ba9fa408_eb07_11eb_9506_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row3_col0" class="data row3 col0" >E30000169</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row3_col1" class="data row3 col1" >Birmingham</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row3_col2" class="data row3 col2" >9593</td>
#             </tr>
#             <tr>
#                         <th id="T_ba9fa408_eb07_11eb_9506_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row4_col0" class="data row4 col0" >E30000237</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row4_col1" class="data row4 col1" >Luton</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row4_col2" class="data row4 col2" >8873</td>
#             </tr>
#             <tr>
#                         <th id="T_ba9fa408_eb07_11eb_9506_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row5_col0" class="data row5 col0" >E30000175</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row5_col1" class="data row5 col1" >Bournemouth</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row5_col2" class="data row5 col2" >7546</td>
#             </tr>
#             <tr>
#                         <th id="T_ba9fa408_eb07_11eb_9506_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row6_col0" class="data row6 col0" >E30000179</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row6_col1" class="data row6 col1" >Brighton</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row6_col2" class="data row6 col2" >7483</td>
#             </tr>
#             <tr>
#                         <th id="T_ba9fa408_eb07_11eb_9506_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row7_col0" class="data row7 col0" >E30000186</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row7_col1" class="data row7 col1" >Cambridge</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row7_col2" class="data row7 col2" >6252</td>
#             </tr>
#             <tr>
#                         <th id="T_ba9fa408_eb07_11eb_9506_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row8_col0" class="data row8 col0" >E30000180</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row8_col1" class="data row8 col1" >Bristol</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row8_col2" class="data row8 col2" >6176</td>
#             </tr>
#             <tr>
#                         <th id="T_ba9fa408_eb07_11eb_9506_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row9_col0" class="data row9 col0" >E30000212</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row9_col1" class="data row9 col1" >Guildford and Aldershot</td>
#                         <td id="T_ba9fa408_eb07_11eb_9506_acde48001122row9_col2" class="data row9 col2" >5986</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# filter data by ttwa

# %%
# df_10_tc means "top 10 tech ttwa clusters"
df_10_tc = df.copy()
print(df_10_tc.shape)

# filter data to top 10 ttwa data raws
df_10_tc = df_10_tc[df_10_tc.ttwa.isin(df_ttwa_10.ttwa_code.to_list())]
print(df_10_tc.shape)
# Out:
# (423634, 64)
# (206557, 64)

# %% [markdown]
# filter data by birth year

# %%
print(df_10_tc.shape)
# df_10_tc_20 means "top 10 tech ttwa clusters in 20 years dataframe"
df_10_tc_20 = df_10_tc[df_10_tc["birth_year"]>=1998]
print(df_10_tc_20.shape)
# Out:
# (206557, 64)
# (196071, 64)

# %%
df_10_tc_20 = df_10_tc_20.reset_index().drop("index",axis=1)
df_10_tc_20.head()
# Out:
#   registered_number incorporation_date dissolution_date  \
# 0          07341142         2010-08-10              NaN
# 1          10490667         2016-11-22              NaN
# 2          11283731         2018-03-29              NaN
# 3          09852054         2015-11-02              NaN
# 4          08577485         2013-06-20              NaN
#
#                       latest_accounts_cash  \
# 0                                      nan
# 1                                      nan
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#                     latest_accounts_assets  \
# 0                              56,331.0000
# 1                              11,254.0000
# 2                                      nan
# 3                              20,002.0000
# 4                               8,390.0000
#
#                latest_accounts_liabilities  year_obs  \
# 0                                      nan      2017
# 1                                      nan      2018
# 2                                      nan      2018
# 3                                      nan      2017
# 4                              11,888.0000      2017
#
#                                   sic_year  \
# 0                               2,007.0000
# 1                               2,007.0000
# 2                               2,007.0000
# 3                               2,007.0000
# 4                               2,007.0000
#
#                                       sic4  \
# 0                               6,202.0000
# 1                               7,211.0000
# 2                               6,201.0000
# 3                               6,201.0000
# 4                               8,621.0000
#
#                                 change_sic  ...      pcd2     pcds        cty  \
# 0                                   0.0000  ...  AL1  1AJ  AL1 1AJ  E10000015
# 1                                   0.0000  ...  AL1  1AU  AL1 1AU  E10000015
# 2                                   0.0000  ...  AL1  1DG  AL1 1DG  E10000015
# 3                                   0.0000  ...  AL1  1DG  AL1 1DG  E10000015
# 4                                   0.0000  ...  AL1  1DS  AL1 1DS  E10000015
#
#         laua       ctry        rgn       ttwa        pct       lep1 lep2
# 0  E07000240  E92000001  E12000006  E30000237  E16000150  E37000017  NaN
# 1  E07000240  E92000001  E12000006  E30000237  E16000150  E37000017  NaN
# 2  E07000240  E92000001  E12000006  E30000237  E16000150  E37000017  NaN
# 3  E07000240  E92000001  E12000006  E30000237  E16000150  E37000017  NaN
# 4  E07000240  E92000001  E12000006  E30000237  E16000150  E37000017  NaN
#
# [5 rows x 64 columns]

# %% [markdown]
# select the necessary columns

# %%
df2 = df_10_tc_20.copy()

# add other variables
df2 = df2[["registered_number",\
        "ttwa",\
        "birth_year",\
        "diss_year",\
        "latest_accounts_assets"]]

df2.head()
# Out:
#   registered_number       ttwa                               birth_year  \
# 0          07341142  E30000237                               2,010.0000
# 1          10490667  E30000237                               2,016.0000
# 2          11283731  E30000237                               2,018.0000
# 3          09852054  E30000237                               2,015.0000
# 4          08577485  E30000237                               2,013.0000
#
#                                  diss_year  \
# 0                                      nan
# 1                                      nan
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#                     latest_accounts_assets
# 0                              56,331.0000
# 1                              11,254.0000
# 2                                      nan
# 3                              20,002.0000
# 4                               8,390.0000

# %% [markdown]
# - `i` means `ttwa`
# - `t` means `year`

# %%
# export to excel to process
df2.to_excel(PATH + "/Top_10_Tech_TTWA_Cluster_Reg_Prepare.xlsx", index = False)

# %%
df3 = pd.read_excel(PATH + "/Excel/Top_10_Tech_TTWA_Cluster_Reg_Prepare.xlsx",sheet_name = "dynamics")
df3.head()
# Out:
#         ttwa  birth_year  Count_of_tech_firms  \
# 0  E30000169        1998                   57
# 1  E30000169        1999                   78
# 2  E30000169        2000                   82
# 3  E30000169        2001                   67
# 4  E30000169        2002                  125
#
#          Average_of_latest_accounts_assets  Total_tech_firms  \
# 0                             154,110.7632              9047
# 1                             392,610.4737              9047
# 2                             234,658.3898              9047
# 3                             198,533.5192              9047
# 4                             169,835.2778              9047
#
#                                 Entry_Rate
# 0                                   0.0063
# 1                                   0.0086
# 2                                   0.0091
# 3                                   0.0074
# 4                                   0.0138

# %% [markdown]
# ttwa is `categroy`
#
# birth_year - 1998 is `numeric`

# %% [markdown]
# ## EDA & DA(Descriptive Analysis)

# %% [markdown]
# distribution inspect for `Entry_Rate`

# %%
import seaborn as sns
# df = df3[df3["birth_year"]==2013]
# 1/np.square(df3_final['Entry_Rate'])
df = df3.copy()
df.Entry_Rate = np.log(df["Entry_Rate"])
# df.Entry_Rate
sns.displot(df, x="Entry_Rate",bins=120)

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Ideal hypothesis is:

# %% [markdown]
# $ Dynamics\ Variable_{i,t} = a_1 + b_2 \times firms_{i,(t-n)} + b_3 \times industry\ mix_{i,(t-n)} + b_{X,i,(t-n)} + location_i + year_t + e_{i,t} $ (1)

# %% [markdown]
# Change into:

# %% [markdown]
# Hypo 1: $ Dynamics\ Variable_{i,t} = a_1 + b_2 \times firms_{i,t} + b_3 \times location_i + b_4 \times year_t $
#
# Hypo 2: $ Dynamics\ Variable_{i,t} = a_1 + b_2 \times firms_{i,t} + b_3 \times location_i + b_4 \times (year_t - 1998)$
#
# Hypo 3: $ log_e{\ Dynamics\ Variable_{i,t}} = a_1 + b_1 \times firms_{i,t} + b_2 \times location_i + b_3 \times (year_t - 1998)$

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Reg For **Hypo 1**
#
# $ Dynamics\ Variable_{i,t} = a_1 + b_1 \times firms_{i,t} + b_2 \times location_i + b_3 \times year_t $

# %%
# environment preparation

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %%
# data preprocess
df3_1 = df3.copy()

df3_1.birth_year = df3_1.birth_year.astype("str")

df3_1_numeric = pd.get_dummies(df3_1)

df3_1_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 35 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Count_of_tech_firms                210 non-null    int64
#  1   Average_of_latest_accounts_assets  203 non-null    float64
#  2   Total_tech_firms                   210 non-null    int64
#  3   Entry_Rate                         210 non-null    float64
#  4   ttwa_E30000169                     210 non-null    uint8
#  5   ttwa_E30000175                     210 non-null    uint8
#  6   ttwa_E30000179                     210 non-null    uint8
#  7   ttwa_E30000180                     210 non-null    uint8
#  8   ttwa_E30000186                     210 non-null    uint8
#  9   ttwa_E30000212                     210 non-null    uint8
#  10  ttwa_E30000234                     210 non-null    uint8
#  11  ttwa_E30000237                     210 non-null    uint8
#  12  ttwa_E30000239                     210 non-null    uint8
#  13  ttwa_E30000266                     210 non-null    uint8
#  14  birth_year_1998                    210 non-null    uint8
#  15  birth_year_1999                    210 non-null    uint8
#  16  birth_year_2000                    210 non-null    uint8
#  17  birth_year_2001                    210 non-null    uint8
#  18  birth_year_2002                    210 non-null    uint8
#  19  birth_year_2003                    210 non-null    uint8
#  20  birth_year_2004                    210 non-null    uint8
#  21  birth_year_2005                    210 non-null    uint8
#  22  birth_year_2006                    210 non-null    uint8
#  23  birth_year_2007                    210 non-null    uint8
#  24  birth_year_2008                    210 non-null    uint8
#  25  birth_year_2009                    210 non-null    uint8
#  26  birth_year_2010                    210 non-null    uint8
#  27  birth_year_2011                    210 non-null    uint8
#  28  birth_year_2012                    210 non-null    uint8
#  29  birth_year_2013                    210 non-null    uint8
#  30  birth_year_2014                    210 non-null    uint8
#  31  birth_year_2015                    210 non-null    uint8
#  32  birth_year_2016                    210 non-null    uint8
#  33  birth_year_2017                    210 non-null    uint8
#  34  birth_year_2018                    210 non-null    uint8
# dtypes: float64(2), int64(2), uint8(31)
# memory usage: 13.0 KB

# %%
df3_1_final = df3_1_numeric.drop(['ttwa_E30000169', 'birth_year_1998'], axis=1)

# preprocess: drop na values
df3_1_final = df3_1_final.dropna(subset = ["Average_of_latest_accounts_assets"])

# double check the result
df3_1_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 203 entries, 0 to 208
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Count_of_tech_firms                203 non-null    int64
#  1   Average_of_latest_accounts_assets  203 non-null    float64
#  2   Total_tech_firms                   203 non-null    int64
#  3   Entry_Rate                         203 non-null    float64
#  4   ttwa_E30000175                     203 non-null    uint8
#  5   ttwa_E30000179                     203 non-null    uint8
#  6   ttwa_E30000180                     203 non-null    uint8
#  7   ttwa_E30000186                     203 non-null    uint8
#  8   ttwa_E30000212                     203 non-null    uint8
#  9   ttwa_E30000234                     203 non-null    uint8
#  10  ttwa_E30000237                     203 non-null    uint8
#  11  ttwa_E30000239                     203 non-null    uint8
#  12  ttwa_E30000266                     203 non-null    uint8
#  13  birth_year_1999                    203 non-null    uint8
#  14  birth_year_2000                    203 non-null    uint8
#  15  birth_year_2001                    203 non-null    uint8
#  16  birth_year_2002                    203 non-null    uint8
#  17  birth_year_2003                    203 non-null    uint8
#  18  birth_year_2004                    203 non-null    uint8
#  19  birth_year_2005                    203 non-null    uint8
#  20  birth_year_2006                    203 non-null    uint8
#  21  birth_year_2007                    203 non-null    uint8
#  22  birth_year_2008                    203 non-null    uint8
#  23  birth_year_2009                    203 non-null    uint8
#  24  birth_year_2010                    203 non-null    uint8
#  25  birth_year_2011                    203 non-null    uint8
#  26  birth_year_2012                    203 non-null    uint8
#  27  birth_year_2013                    203 non-null    uint8
#  28  birth_year_2014                    203 non-null    uint8
#  29  birth_year_2015                    203 non-null    uint8
#  30  birth_year_2016                    203 non-null    uint8
#  31  birth_year_2017                    203 non-null    uint8
#  32  birth_year_2018                    203 non-null    uint8
# dtypes: float64(2), int64(2), uint8(29)
# memory usage: 13.7 KB

# %%
predictors_df3 = df3_1_final.drop('Entry_Rate', axis=1)
response_df3 = df3_1_final['Entry_Rate']

# fit a lineare regression model using statsmodel
hypo1_regressor_OLS = sm.OLS(endog=response_df3, exog=sm.add_constant(predictors_df3)).fit()
hypo1_regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Entry_Rate   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     112.0
# Date:                Mon, 26 Jul 2021   Prob (F-statistic):           1.44e-97
# Time:                        01:22:08   Log-Likelihood:                 681.11
# No. Observations:                 203   AIC:                            -1298.
# Df Residuals:                     171   BIC:                            -1192.
# Df Model:                          31
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 0.0032      0.004      0.714      0.476      -0.006       0.012
# Count_of_tech_firms                 1.47e-06   4.65e-07      3.162      0.002    5.52e-07    2.39e-06
# Average_of_latest_accounts_assets  2.806e-08   1.11e-08      2.520      0.013    6.08e-09    5.01e-08
# Total_tech_firms                  -8.199e-08   3.29e-08     -2.494      0.014   -1.47e-07   -1.71e-08
# ttwa_E30000175                       -0.0018      0.003     -0.601      0.548      -0.008       0.004
# ttwa_E30000179                        0.0015      0.003      0.496      0.621      -0.004       0.007
# ttwa_E30000180                        0.0016      0.003      0.528      0.598      -0.004       0.007
# ttwa_E30000186                       -0.0020      0.003     -0.676      0.500      -0.008       0.004
# ttwa_E30000212                        0.0016      0.003      0.548      0.584      -0.004       0.007
# ttwa_E30000234                       -0.0003      0.000     -0.688      0.492      -0.001       0.001
# ttwa_E30000237                       -0.0009      0.003     -0.304      0.761      -0.007       0.005
# ttwa_E30000239                        0.0003      0.003      0.104      0.917      -0.005       0.006
# ttwa_E30000266                        0.0007      0.003      0.240      0.811      -0.005       0.006
# birth_year_1999                      -0.0008      0.004     -0.205      0.838      -0.009       0.007
# birth_year_2000                       0.0013      0.004      0.317      0.751      -0.007       0.009
# birth_year_2001                      -0.0020      0.004     -0.473      0.637      -0.010       0.006
# birth_year_2002                       0.0061      0.004      1.473      0.143      -0.002       0.014
# birth_year_2003                       0.0098      0.004      2.354      0.020       0.002       0.018
# birth_year_2004                       0.0076      0.004      1.811      0.072      -0.001       0.016
# birth_year_2005                       0.0105      0.004      2.479      0.014       0.002       0.019
# birth_year_2006                       0.0125      0.004      2.987      0.003       0.004       0.021
# birth_year_2007                       0.0245      0.004      5.602      0.000       0.016       0.033
# birth_year_2008                       0.0189      0.004      4.451      0.000       0.011       0.027
# birth_year_2009                       0.0222      0.004      5.165      0.000       0.014       0.031
# birth_year_2010                       0.0346      0.004      7.800      0.000       0.026       0.043
# birth_year_2011                       0.0450      0.005      9.975      0.000       0.036       0.054
# birth_year_2012                       0.0555      0.005     12.156      0.000       0.047       0.065
# birth_year_2013                       0.0666      0.005     14.331      0.000       0.057       0.076
# birth_year_2014                       0.0851      0.005     18.082      0.000       0.076       0.094
# birth_year_2015                       0.1004      0.005     20.630      0.000       0.091       0.110
# birth_year_2016                       0.0988      0.005     20.222      0.000       0.089       0.108
# birth_year_2017                       0.1051      0.005     21.333      0.000       0.095       0.115
# birth_year_2018                       0.1430      0.007     20.130      0.000       0.129       0.157
# ==============================================================================
# Omnibus:                      115.665   Durbin-Watson:                   0.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1400.383
# Skew:                           1.874   Prob(JB):                    8.14e-305
# Kurtosis:                      15.309   Cond. No.                     1.35e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.55e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
plt.scatter(hypo1_regressor_OLS.fittedvalues, hypo1_regressor_OLS.resid)
# adding title and labels
plt.xlabel('Fitted Y')
plt.ylabel('Residual')
plt.title('Figure')
plt.ylim(-0.1,0.1)
plt.show()

# %% [markdown]
# ### Reg For **Hypo 2**
#
# $ Dynamics\ Variable_{i,t} = a_1 + b_1 \times firms_{i,t} + b_2 \times location_i + b_3 \times (year_t - 1998)$

# %%
df3_2 = df3.copy()

df3_2.birth_year = df3_2.birth_year.astype("int")
df3_2_numeric = pd.get_dummies(df3_2)
df3_2_numeric = df3_2_numeric.drop(['ttwa_E30000169'], axis=1)

# preprocess drop na
df3_2_final = df3_2_numeric.dropna(subset = ["Average_of_latest_accounts_assets"])

# drop Birmingham for dummies variables comparasion
# df3_2_final = df3_2_numeric.drop("ttwa_E30000169",axis=1)

df = df3_2_final
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def drop_column_using_vif_(df, list_var_not_to_remove, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe, and repeatedly drop the columns with the highest VIF
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param list_var_not_to_remove: the list of variables that should not be removed even though it has a high VIF. For example, dummy (or indicator) variables represent a categorical variable with three or more categories.
    :param thresh: the max VIF value before the feature is removed from the dataframe
    :return: dataframe with multicollinear features removed
    '''
    while True:
        # adding a constatnt item to the data
        df_with_const = add_constant(df)

        vif_df = pd.Series([variance_inflation_factor(df_with_const.values, i) 
               for i in range(df_with_const.shape[1])], name= "VIF",
              index=df_with_const.columns).to_frame()

        # drop the const
        vif_df = vif_df.drop('const').drop(list_var_not_to_remove)
        
        print('Max VIF:', vif_df.VIF.max())
        
        # if the largest VIF is above the thresh, remove a variable with the largest VIF
        if vif_df.VIF.max() > thresh:
            # If there are multiple variables with the maximum VIF, choose the first one
            index_to_drop = vif_df.index[vif_df.VIF == vif_df.VIF.max()].tolist()[0]
            print('Dropping: {}'.format(index_to_drop))
            df = df.drop(columns = index_to_drop)
        else:
            # No VIF is above threshold. Exit the loop
            break

    return df

predictors_df3 = df3_2_final.drop('Entry_Rate', axis=1)
response_df3 = df3_2_final['Entry_Rate']

# this is a list of dummy variables that represent a categorical variable with three or more categories. They should not be removed even if it has a high VIF. 
# list_var_not_to_remove = ['ttwa_E30000234', 'Count_of_tech_firms', 'Total_tech_firms']
list_var_not_to_remove = ["ttwa_E30000234"]
df_predictors_select_VIF = drop_column_using_vif_(predictors_df3, list_var_not_to_remove, thresh=5)
print("The columns remaining after VIF selection are:")
print(df_predictors_select_VIF.columns)
# Out:
# Max VIF: inf
# Dropping: Total_tech_firms
# Max VIF: 2.921082332285599
# The columns remaining after VIF selection are:
# Index(['birth_year', 'Count_of_tech_firms',
#        'Average_of_latest_accounts_assets', 'ttwa_E30000175', 'ttwa_E30000179',
#        'ttwa_E30000180', 'ttwa_E30000186', 'ttwa_E30000212', 'ttwa_E30000234',
#        'ttwa_E30000237', 'ttwa_E30000239', 'ttwa_E30000266'],
#       dtype='object')
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
hypo2_regressor_OLS = sm.OLS(endog=response_df3, exog=sm.add_constant(df_predictors_select_VIF)).fit()
hypo2_regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Entry_Rate   R-squared:                       0.838
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     81.90
# Date:                Mon, 26 Jul 2021   Prob (F-statistic):           2.53e-68
# Time:                        01:23:14   Log-Likelihood:                 555.40
# No. Observations:                 203   AIC:                            -1085.
# Df Residuals:                     190   BIC:                            -1042.
# Df Model:                          12
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                               -11.5268      0.668    -17.259      0.000     -12.844     -10.209
# birth_year                            0.0058      0.000     17.358      0.000       0.005       0.006
# Count_of_tech_firms                4.046e-06    7.6e-07      5.323      0.000    2.55e-06    5.55e-06
# Average_of_latest_accounts_assets  3.257e-08   1.77e-08      1.838      0.068   -2.39e-09    6.75e-08
# ttwa_E30000175                       -0.0012      0.005     -0.240      0.811      -0.011       0.009
# ttwa_E30000179                        0.0041      0.005      0.807      0.421      -0.006       0.014
# ttwa_E30000180                        0.0022      0.005      0.422      0.673      -0.008       0.012
# ttwa_E30000186                       -0.0014      0.005     -0.277      0.782      -0.012       0.009
# ttwa_E30000212                        0.0022      0.005      0.428      0.669      -0.008       0.012
# ttwa_E30000234                       -0.0199      0.006     -3.234      0.001      -0.032      -0.008
# ttwa_E30000237                       -0.0008      0.005     -0.156      0.877      -0.011       0.009
# ttwa_E30000239                        0.0007      0.005      0.142      0.887      -0.009       0.011
# ttwa_E30000266                       -0.0008      0.005     -0.148      0.883      -0.011       0.009
# ==============================================================================
# Omnibus:                       44.698   Durbin-Watson:                   0.499
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.296
# Skew:                           1.074   Prob(JB):                     1.82e-19
# Kurtosis:                       5.364   Cond. No.                     1.04e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Then, the residual analysis is conducted to test the regression performance

# %%
plt.scatter(hypo2_regressor_OLS.fittedvalues, hypo2_regressor_OLS.resid)
# adding title and labels
plt.xlabel('Fitted cases rate 1')
plt.ylabel('Residual')
plt.title('Figure')
plt.ylim(-0.5,0.5)
plt.show()

# %% [markdown]
# ### Reg For **Hypo 3**
#
# $ log_e{\ Dynamics\ Variable_{i,t}} = a_1 + b_1 \times firms_{i,t} + b_2 \times location_i + b_3 \times (year_t - 1998)$

# %%
df3_3_final = df3_2_final.copy()

predictors_df3 = df3_3_final.drop('Entry_Rate', axis=1)
response_df3 = np.log(df3_3_final['Entry_Rate'])

# this is a list of dummy variables that represent a categorical variable with three or more categories. They should not be removed even if it has a high VIF. 
# list_var_not_to_remove = ['ttwa_E30000234', 'Count_of_tech_firms', 'Total_tech_firms']
list_var_not_to_remove = ["ttwa_E30000234","birth_year","Average_of_latest_accounts_assets"]
df_predictors_select_VIF = drop_column_using_vif_(predictors_df3, list_var_not_to_remove, thresh=2.5)
print("The columns remaining after VIF selection are:")
print(df_predictors_select_VIF.columns)

hypo3_regressor_OLS = sm.OLS(endog=response_df3, exog=sm.add_constant(df_predictors_select_VIF)).fit()
hypo3_regressor_OLS.summary()
# Out:
# Max VIF: inf
# Dropping: Total_tech_firms
# Max VIF: 2.51254206349312
# Dropping: Count_of_tech_firms
# Max VIF: 1.8588682111679997
# The columns remaining after VIF selection are:
# Index(['birth_year', 'Average_of_latest_accounts_assets', 'ttwa_E30000175',
#        'ttwa_E30000179', 'ttwa_E30000180', 'ttwa_E30000186', 'ttwa_E30000212',
#        'ttwa_E30000234', 'ttwa_E30000237', 'ttwa_E30000239', 'ttwa_E30000266'],
#       dtype='object')
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Entry_Rate   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     232.4
# Date:                Mon, 26 Jul 2021   Prob (F-statistic):          3.35e-104
# Time:                        20:35:58   Log-Likelihood:                -11.498
# No. Observations:                 203   AIC:                             47.00
# Df Residuals:                     191   BIC:                             86.75
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                              -326.0186      9.012    -36.176      0.000    -343.794    -308.243
# birth_year                            0.1606      0.004     35.882      0.000       0.152       0.169
# Average_of_latest_accounts_assets  3.283e-07   2.66e-07      1.235      0.219   -1.96e-07    8.53e-07
# ttwa_E30000175                       -0.4842      0.084     -5.759      0.000      -0.650      -0.318
# ttwa_E30000179                       -0.1412      0.083     -1.702      0.090      -0.305       0.022
# ttwa_E30000180                        0.1353      0.083      1.621      0.107      -0.029       0.300
# ttwa_E30000186                        0.1101      0.084      1.317      0.189      -0.055       0.275
# ttwa_E30000212                        0.2307      0.084      2.758      0.006       0.066       0.396
# ttwa_E30000234                       -0.0864      0.085     -1.017      0.310      -0.254       0.081
# ttwa_E30000237                       -0.0481      0.084     -0.576      0.565      -0.213       0.117
# ttwa_E30000239                        0.0134      0.083      0.163      0.871      -0.149       0.176
# ttwa_E30000266                        0.0327      0.083      0.391      0.696      -0.132       0.197
# ==============================================================================
# Omnibus:                        4.739   Durbin-Watson:                   1.039
# Prob(Omnibus):                  0.094   Jarque-Bera (JB):                4.488
# Skew:                           0.279   Prob(JB):                        0.106
# Kurtosis:                       3.468   Cond. No.                     8.64e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.64e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(hypo3_regressor_OLS.fittedvalues, hypo3_regressor_OLS.resid)
# adding title and labels
plt.xlabel('Fitted Dynamics Variables after Logarithmic Transformation')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Plot of Dynamics Variables')
plt.ylim(-2,2)
plt.show()

# %%
fig1 = plt.figure(figsize=(12,8))
fig1 = sm.graphics.plot_regress_exog(hypo3_regressor_OLS, 'birth_year', fig=fig1)

# %% [markdown]
# ## ARIMA OLS

# %%
# data preparasion
df4 = df3.copy()
print(df3.shape)
df4 = df4.dropna(subset=["Average_of_latest_accounts_assets"])
print(df4.shape)
df4.head()
# Out:
# (210, 6)
# (203, 6)
#         ttwa  birth_year  Count_of_tech_firms  \
# 0  E30000169        1998                   57
# 1  E30000169        1999                   78
# 2  E30000169        2000                   82
# 3  E30000169        2001                   67
# 4  E30000169        2002                  125
#
#          Average_of_latest_accounts_assets  Total_tech_firms  \
# 0                             154,110.7632              9047
# 1                             392,610.4737              9047
# 2                             234,658.3898              9047
# 3                             198,533.5192              9047
# 4                             169,835.2778              9047
#
#                                 Entry_Rate
# 0                                   0.0063
# 1                                   0.0086
# 2                                   0.0091
# 3                                   0.0074
# 4                                   0.0138
