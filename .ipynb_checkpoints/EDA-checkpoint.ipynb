# %% [markdown]
# # 1 Key Results
#
# 1. choropleth map: Spatial Distribution of the number of tech firms cluster in UK Local Authorities
# 2. bar chart: Top 10 local authorities with the largest number of technology companies in the UK
# 3. table: Possible movers for tech firms
#
# Question: The tech industry contains many industries (i.e. many SICs), but the LQs represent a specific industry index in a specific area (1:1). How to measure tech cluster's LQs in a specific area? (maybe using the average or weighted method?)

# %% [markdown]
# The top 10 number of tech firms for TTWA is given below

# %%
f1_ttwa

# %%
f2_ttwa

# %%
f1_laua

# %%
f2_laua

# %% [markdown]
# - Top 4(the Camden, Westminster, Hackney and Islington clusters) belongs to the London
#
# - Only Brighton and Hove, Birmingham, Manchester and Leeds do **not** belong to London

# %%
possible_tech_movers
# Out:
#        registered_number incorporation_date dissolution_date  \
# 164178           3060979         1995-05-24              NaN
# 144252          07418654         2010-10-25              NaN
# 279459          11632107         2018-10-19              NaN
# 182708          06250619         2007-05-17              NaN
# 228143          08424152         2013-02-28              NaN
# 512012           1981640         1986-01-23              NaN
# 157297          SC583384         2017-12-07              NaN
# 285768           7460781         2010-12-06              NaN
# 20379           11059998         2017-11-13              NaN
# 469818          05608171         2005-11-01              NaN
# 213430          11634444         2018-10-22              NaN
# 323343          11143790         2018-01-10              NaN
# 12019            8070874         2012-05-16              NaN
# 211689          06219671         2007-04-19              NaN
# 140510           7744742         2011-08-18              NaN
# 39534            5631136         2005-11-21              NaN
# 271030          04397427         2002-03-18              NaN
# 19904           09552070         2015-04-21              NaN
# 387395          11065921         2017-11-15              NaN
# 241453          11412829         2018-06-13              NaN
# 47123            8546782         2013-05-28              NaN
# 224545           6598405         2008-05-20              NaN
# 242014           3937810         2000-03-01              NaN
# 511527          10797308         2017-06-01              NaN
# 291684          10589202         2017-01-30              NaN
# 143676          11613438         2018-10-09              NaN
# 424940           9549356         2015-04-19              NaN
# 72656           04405957         2002-03-28              NaN
# 133614          11306057         2018-04-12              NaN
# 326148          10219186         2016-06-07              NaN
# 8204             7998847         2012-03-20              NaN
# 39799           10674075         2017-03-16              NaN
# 323418           9252531         2014-10-07              NaN
# 153204          09331890         2014-11-28              NaN
# 192884           9989675         2016-02-05              NaN
# 407150           7745467         2011-08-18              NaN
# 33981           11438196         2018-06-28              NaN
# 215822          11233132         2018-03-05              NaN
# 332492           6329371         2007-07-31              NaN
# 268281           8922191         2014-03-04              NaN
# 180039          05549948         2005-08-31              NaN
# 494527          11567756         2018-09-13              NaN
# 368604           8417509         2013-02-25              NaN
# 398016           8817694         2013-12-17              NaN
# 151594          11487977         2018-07-27              NaN
# 491599           9732240         2015-08-13              NaN
#
#                             normalised_name postcode
# 164178                      agility limited   EN49HN
# 144252                      agility limited  EC1V2NX
# 279459                     amd tech limited   N156RH
# 182708                     amd tech limited   GL53PN
# 228143           conversion company limited   KT70RY
# 512012           conversion company limited  YO211QL
# 157297                       create limited  EH107DU
# 285768                       create limited    N17GU
# 20379                        ctrl z limited  BA113EE
# 469818                       ctrl z limited   W1T6AD
# 213430  entertainment international limited  IG110GH
# 323343  entertainment international limited   NW51EN
# 12019                    eye clinic limited   B288EZ
# 211689                   eye clinic limited   HU53TS
# 140510           future corporation limited    E83DL
# 39534            future corporation limited   BL26RT
# 271030           globex corporation limited  MK428TU
# 19904            globex corporation limited   B976HR
# 387395              grace and grace limited   SE64EJ
# 241453              grace and grace limited  LL116UG
# 47123                     hit reset limited   BN16AF
# 224545                    hit reset limited  KT168PD
# 242014                         hive limited  LL181RF
# 511527                         hive limited  YO126HT
# 291684                      jc film limited    N32JU
# 143676                      jc film limited  EC1R0DU
# 424940                  jd software limited  SW152BF
# 72656                   jd software limited  CB249AD
# 133614                              limited   E162DQ
# 326148                              limited   NW99NL
# 8204                mak corporation limited   B112AA
# 39799               mak corporation limited   BL35AZ
# 323418                   mind music limited   NW51UA
# 153204                   mind music limited  EC2R6AY
# 192884       quality care solutions limited   HA12SP
# 407150       quality care solutions limited   SN33AJ
# 33981                       red red limited  BH149NY
# 215822                      red red limited   IG45HQ
# 332492                       sar uk limited   OX46NG
# 268281                       sar uk limited   MK11SW
# 180039             solutions design limited  GL170PZ
# 494527             solutions design limited  WC2H9JQ
# 368604              sri corporation limited   S117AQ
# 398016              sri corporation limited   SL11UA
# 151594                  we unicorns limited  EC2A4NE
# 491599                  we unicorns limited  WC2H7LA

# %% [markdown]
# - The number of movers are small (64 records for tech firms)
# - I plan to draw the direction of their movement
# - I plan to explore `asset`,`incorporation_date` or other columns to find other characters of movers

# %% [markdown]
# ---
# # 2 Reproducible Exploratory Data Analysis(EDA)

# %%
# set the local word path 
import sys
PATH = sys.path[0]

# %% [markdown]
# ## 2.1 Read Data

# %%
# read the tech firm records in fame_OC (15GB)
import pandas as pd
df = pd.read_csv(PATH + "/Dataset/fame_OC_tech_firm.csv",low_memory=True)

# preprocess the data
df = df.drop({"Unnamed: 0","Unnamed: 0.1","Unnamed: 0.1.1","is_tech"},axis = 1)
df.head()
# Out:
# /Users/fangzeqiang/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3,28,41,66) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   registered_number incorporation_date dissolution_date  latest_accounts_cash  \
# 0          06199872         2007-04-02              NaN                   NaN
# 1          11896710                NaN              NaN                   NaN
# 2          SC041753         1965-02-19              NaN                   NaN
# 3          12125173                NaN              NaN                   NaN
# 4          11968595                NaN              NaN                   NaN
#
#    latest_accounts_assets  latest_accounts_liabilities  year_obs  sic_year  \
# 0                 15785.0                          NaN      2017    2007.0
# 1                     NaN                          NaN      2018       NaN
# 2                     NaN                          NaN      2018    2007.0
# 3                     NaN                          NaN      2018       NaN
# 4                     NaN                          NaN      2018       NaN
#
#      sic4  change_sic  ...  pcd2 pcds  cty laua ctry  rgn  ttwa  pct lep1 lep2
# 0  8622.0         0.0  ...   NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 1     NaN         NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 2  2013.0         0.0  ...   NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 3     NaN         NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 4     NaN         NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
#
# [5 rows x 64 columns]

# %%
# read the OC1-3
import pandas as pd
df_OC_1_1 = pd.read_csv(PATH + "/Dataset/OC_1_1.csv",low_memory=True)
# df_OC_1_2 = pd.read_csv(PATH + "/Dataset/OC_2_1.csv",low_memory=True)
# df_OC_1_3 = pd.read_csv(PATH + "/Dataset/OC_3_1.csv",low_memory=True)

# proccess the OC_1_1 data
df_OC_1_1 = df_OC_1_1.drop({"Unnamed: 0"},axis=1)
df_OC_1_1.head()
# Out:
# /Users/fangzeqiang/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   registered_number bvd_id          id registered_addresspostal_code  \
# 0               118    NaN    233927.0                      TN23 1DA
# 1               258    NaN  12022629.0                      RG12 1AN
# 2               371    NaN   2111477.0                      SW1Y 6BN
# 3               402    NaN   2302906.0                       PL4 0RA
# 4               425    NaN   3310625.0                      EC4Y 8BB
#
#   primaryaddresspostcodeifuk alltradingaddressespostcodeifuk    sic4  \
# 0                        NaN                             NaN  4611.0
# 1                        NaN                             NaN  7499.0
# 2                        NaN                             NaN  7499.0
# 3                        NaN                             NaN  7499.0
# 4                        NaN                             NaN     NaN
#
#    birth_year  diss_year streetnobuildingetcline1  ...         country  \
# 0      1856.0        NaN   The New Ashford Market  ...  United Kingdom
# 1      1856.0        NaN          India Buildings  ...  United Kingdom
# 2      1863.0        NaN        St Clements House  ...  United Kingdom
# 3      1863.0        NaN             Millbay Road  ...  United Kingdom
# 4      1856.0     2014.0             Surrey House  ...  United Kingdom
#
#   countryisocode                                    regionincountry  \
# 0             GB       England|South Eastern|Tonbridge (TN)|Ashford
# 1             GB         England|North West|Liverpool (L)|Liverpool
# 2             GB               England|Eastern|Norwich (NR)|Norwich
# 3             GB       England|South Western|Plymouth (PL)|Plymouth
# 4             GB  England|London Outer|Kingston Upon Thames (KT)...
#
#              typeofregionincountry telephonenumber faxnumber      addresstype  \
# 0  Country|Region|Postal area|Town     01233506201       NaN  Trading address
# 1  Country|Region|Postal area|Town             NaN       NaN  Trading address
# 2  Country|Region|Postal area|Town             NaN       NaN  Trading address
# 3  Country|Region|Postal area|Town     01752275850       NaN  Trading address
# 4  Country|Region|Postal area|Town             NaN       NaN  Trading address
#
#   address_group isdup_t_postcode       _merge
# 0           1.0                0  matched (3)
# 1           1.0                0  matched (3)
# 2           1.0                0  matched (3)
# 3           1.0                0  matched (3)
# 4           1.0                0  matched (3)
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 2.2 Missing Value Detect

# %%
# find the tech_firm_fame_OC missing value
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.style
# Out:
# <style  type="text/css" >
# </style><table id="T_f7f88390_d29a_11eb_a8f2_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>        <th class="col_heading level0 col1" >Percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row0" class="row_heading level0 row0" >dissolution_date</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row0_col0" class="data row0 col0" >512706</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row0_col1" class="data row0 col1" >0.998049</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row1" class="row_heading level0 row1" >diss_year</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row1_col0" class="data row1 col0" >512706</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row1_col1" class="data row1 col1" >0.998049</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row2" class="row_heading level0 row2" >companieshousenumbersofchildcomp</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row2_col0" class="data row2 col0" >512703</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row2_col1" class="data row2 col1" >0.998044</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row3" class="row_heading level0 row3" >incorporationdate</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row3_col0" class="data row3 col0" >508225</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row3_col1" class="data row3 col1" >0.989327</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row4" class="row_heading level0 row4" >alltradingaddressespostcodeifuk</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row4_col0" class="data row4 col0" >508107</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row4_col1" class="data row4 col1" >0.989097</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row5" class="row_heading level0 row5" >primaryaddresspostcodeifuk</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row5_col0" class="data row5 col0" >508104</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row5_col1" class="data row5 col1" >0.989091</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row6" class="row_heading level0 row6" >numberofchildcompanies</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row6_col0" class="data row6 col0" >508104</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row6_col1" class="data row6 col1" >0.989091</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row7" class="row_heading level0 row7" >companieshousenumbersofcompanies</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row7_col0" class="data row7 col0" >508104</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row7_col1" class="data row7 col1" >0.989091</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row8" class="row_heading level0 row8" >numberofcompaniesinitscorporates</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row8_col0" class="data row8 col0" >508104</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row8_col1" class="data row8 col1" >0.989091</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row9" class="row_heading level0 row9" >registeredname</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row9_col0" class="data row9 col0" >508104</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row9_col1" class="data row9 col1" >0.989091</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row10" class="row_heading level0 row10" >companieshousestatus</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row10_col0" class="data row10 col0" >508104</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row10_col1" class="data row10 col1" >0.989091</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row11" class="row_heading level0 row11" >siccodes2007</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row11_col0" class="data row11 col0" >508104</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row11_col1" class="data row11 col1" >0.989091</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row12" class="row_heading level0 row12" >istheultimateparent</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row12_col0" class="data row12 col0" >508104</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row12_col1" class="data row12 col1" >0.989091</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row13" class="row_heading level0 row13" >latest_accounts_cash</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row13_col0" class="data row13 col0" >493925</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row13_col1" class="data row13 col1" >0.961490</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row14" class="row_heading level0 row14" >latest_accounts_liabilities</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row14_col0" class="data row14 col0" >463134</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row14_col1" class="data row14 col1" >0.901551</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row15" class="row_heading level0 row15" >lep2</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row15_col0" class="data row15 col0" >450192</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row15_col1" class="data row15 col1" >0.876358</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row16" class="row_heading level0 row16" >nr_employees_last_avail_yr</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row16_col0" class="data row16 col0" >349899</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row16_col1" class="data row16 col1" >0.681124</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row17" class="row_heading level0 row17" >latest_accounts_assets</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row17_col0" class="data row17 col0" >255560</td>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde48001122row17_col1" class="data row17 col1" >0.497481</td>
#             </tr>
#             <tr>
#                         <th id="T_f7f88390_d29a_11eb_a8f2_acde48001122level0_row18" class="row_heading level0 row18" >year_accounts</th>
#                         <td id="T_f7f88390_d29a_11eb_a8f2_acde

# %% [markdown]
# detect the OC_1_1 missing value and clean

# %%
# find the OC1-3 missing value
total = df_OC_1_1.isnull().sum().sort_values(ascending=False)
percent = (df_OC_1_1.isnull().sum()/df_OC_1_1.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                                   Total   Percent
# faxnumber                        259581  1.000000
# streetnobuildingetcline4         258103  0.994306
# streetnobuildingetcline4native   258103  0.994306
# alltradingaddressespostcodeifuk  257100  0.990442
# primaryaddresspostcodeifuk       257100  0.990442
# streetnobuildingetcline3native   219300  0.844823
# streetnobuildingetcline3         219300  0.844823
# diss_year                        190576  0.734168
# bvd_id                           176827  0.681202
# telephonenumber                  154869  0.596611
# streetnobuildingetcline2         112826  0.434647
# streetnobuildingetcline2native   112826  0.434647
# sic4                              45985  0.177151
# birth_year                         4844  0.018661
# id                                 4812  0.018538
# regionincountry                    1174  0.004523
# typeofregionincountry              1174  0.004523
# country                            1160  0.004469
# countryisocode                     1160  0.004469
# city                               1157  0.004457
# citynative                         1157  0.004457
# streetnobuildingetcline1native      128  0.000493
# streetnobuildingetcline1            128  0.000493
# registered_addresspostal_code        11  0.000042
# _merge                                0  0.000000
# isdup_t_postcode                      0  0.000000
# postcode                              0  0.000000
# addresstype                           0  0.000000
# address_group                         0  0.000000
# registered_number                     0  0.000000

# %%
# detect the unique value for country columns
df_OC_1_1.country.unique()
# Out:
# array(['United Kingdom', nan, 'Bulgaria', 'Israel',
#        'United States of America', 'Jersey', 'Isle Of Man', 'Guernsey'],
#       dtype=object)

# %%
# drop the columns which contain NA value

df_OC_1_1_dropna = df_OC_1_1.copy()
print(df_OC_1_1_dropna.shape)

for i in df_OC_1_1_dropna.columns:
    # i = str(i)
    if missing_data.Percent[i]!=0:
        df_OC_1_1_dropna = df_OC_1_1_dropna.drop({i},axis = 1)
    # df_OC_1_1 = df_OC_1_1.drop()

print(df_OC_1_1_dropna.shape)

# and we can find there are 6 columns remaining
# Out:
# (259581, 30)
# (259581, 6)

# %% [markdown]
# ## 2.3 Attributes Recap (fame_OC)

# %% [markdown]
# For `tech_firm_fame_OC`, the **temporal variables** are given below:
#
# |Columns|Missing Number|Missing Percentage|
# |--|--:|:--:|
# |dissolution_date |512706 |0.998049|
# |incorporation_date | 88803 |0.172867|
#
# \* 17% incorporation_date are N/A
#
# \* Almost 99% dissolution_date are N/A (most tech firms survive?)
#
# And the **spatial attributes** can be found in the following table:
#
# |Columns|Description|
# |--|--:|
# |Postcode||
# |Pcd2| postcode split by space|
# |Pcds||
# |Cty | City|
# |Laua | Local/Unitary Authority/London Borough|
# |Ctry | Country|
# |Rgn | Region|
# |[Ttwa](https://en.wikipedia.org/wiki/Travel_to_work_area) | [Travel to work area](https://findthatpostcode.uk/areatypes/ttwa.html) |
# |Pct||
#
# \* **4** countries in this dataset
#
# \* **12** regions in dataset

# %%
# value counts & pick spatial info
print(df.cty.value_counts().head(10))
print(df.ctry.value_counts().head(10))
print(df.rgn.value_counts().head(10))
print(df.pct.value_counts().head(10))
# Out:
# E99999999    103979
# E13000001     89257
# E13000002     61739
# S99999999     23186
# E11000001     20208
# E11000005     16697
# E10000015     16026
# E11000006     12808
# E10000030     12709
# E10000014     11698
# Name: cty, dtype: int64
# E92000001    462536
# S92000003     23186
# W92000004     11665
# N92000002      5251
# L93000001        17
# M83000003         3
# Name: ctry, dtype: int64
# E12000007    150996
# E12000008     82673
# E12000006     48720
# E12000002     47983
# E12000009     38636
# E12000005     32348
# E12000003     25910
# E12000004     25049
# S99999999     23186
# W99999999     11665
# Name: rgn, dtype: int64
# E16000010    17612
# E16000150    16026
# E16000047    15897
# E16000107    12613
# E16000057    12069
# E16000133    11698
# E16000048    10271
# E16000143     9157
# E16000063     8026
# E16000006     7023
# Name: pct, dtype: int64

# %% [markdown]
# To merge the `cty, ctry, rgn, pct` name , I refer to `uk city country region pct code lookup`

# %%
df_code_lookup = pd.read_csv(PATH + "/Dataset/Code_History_Database_(June_2021)_UK/Equivalents.csv")
df_code_lookup = df_code_lookup[["GEOGCD","GEOGNM"]]
df_code_lookup.columns = ["code","name"]
df_code_lookup = df_code_lookup.dropna()
df_code_lookup.head()
# Out:
# /Users/fangzeqiang/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,2,4,5,6,7,8,9,10,13,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           code                name
# 407  E32000001   Barnet and Camden
# 408  E32000002  Bexley and Bromley
# 409  E32000003    Brent and Harrow
# 410  E32000004       City and East
# 411  E32000005  Croydon and Sutton

# %%
df_cty = pd.DataFrame(df.cty.value_counts().head(10)).reset_index()
df_ctry = pd.DataFrame(df.ctry.value_counts().head(10)).reset_index()
df_rgn = pd.DataFrame(df.rgn.value_counts().head(10)).reset_index()

#-----

df_cty.columns = ["city","counts"]
df_ctry.columns = ["country","counts"]
df_rgn.columns = ["region","counts"]


#-----

df_cty_name = pd.merge(df_cty,df_code_lookup,left_on="city", right_on="code")
df_ctry_name = pd.merge(df_ctry,df_code_lookup,left_on="country", right_on="code")
df_rgn_name = pd.merge(df_rgn,df_code_lookup,left_on="region", right_on="code")

df_cty_name = df_cty_name[["city","name","counts"]]
df_ctry_name = df_ctry_name[["country","name","counts"]]
df_rgn_name = df_rgn_name[["region","name","counts"]]

print(df_cty)
print(df_cty_name)
print("\n")
print(df_ctry_name)
print("\n")
print(df_rgn_name)
# Out:
#         city  counts
# 0  E99999999  103979
# 1  E13000001   89257
# 2  E13000002   61739
# 3  S99999999   23186
# 4  E11000001   20208
# 5  E11000005   16697
# 6  E10000015   16026
# 7  E11000006   12808
# 8  E10000030   12709
# 9  E10000014   11698
#         city                name  counts
# 0  E11000001  Greater Manchester   20208
# 1  E11000005       West Midlands   16697
# 2  E10000015       Hertfordshire   16026
# 3  E10000015       Hertfordshire   16026
# 4  E11000006      West Yorkshire   12808
# 5  E10000030              Surrey   12709
# 6  E10000030              Surrey   12709
# 7  E10000014           Hampshire   11698
# 8  E10000014           Hampshire   11698
#
#
#      country              name  counts
# 0  E92000001           England  462536
# 1  S92000003          Scotland   23186
# 2  W92000004             Wales   11665
# 3  N92000002  Northern Ireland    5251
#
#
#       region                      name  counts
# 0  E12000007                    London  150996
# 1  E12000008                South East   82673
# 2  E12000006           East of England   48720
# 3  E12000002                North West   47983
# 4  E12000009                South West   38636
# 5  E12000005             West Midlands   32348
# 6  E12000003  Yorkshire and The Humber   25910
# 7  E12000004             East Midlands   25049

# %%
# import the major city & town
import geopandas as gpd
g_city = gpd.read_file(PATH + "/Dataset/Spatial/Major_Towns_and_Cities_(December_2015)_Boundaries_V2.geojson")
g_city.head()
# Out:
#    OBJECTID  TCITY15CD    TCITY15NM   BNG_E   BNG_N      LONG       LAT  \
# 0         1  J01000001     Barnsley  436375  407875 -1.452250  53.56625
# 1         2  J01000002     Basildon  572525  189350  0.488409  51.57661
# 2         3  J01000003  Basingstoke  463725  152600 -1.087930  51.26899
# 3         4  J01000004         Bath  374800  164325 -2.363450  51.37741
# 4         5  J01000005      Bedford  505925  250450 -0.453520  52.14220
#
#     Shape__Area  Shape__Length  \
# 0  2.568247e+07  115099.860000
# 1  2.551499e+07  119299.838000
# 2  2.918502e+07   93900.388003
# 3  2.423750e+07   92099.940000
# 4  2.016749e+07   71300.186000
#
#                                             geometry
# 0  POLYGON ((-1.51420 53.59640, -1.51344 53.59640...
# 1  MULTIPOLYGON (((0.41119 51.59711, 0.41117 51.5...
# 2  POLYGON ((-1.04625 51.29205, -1.04696 51.29205...
# 3  MULTIPOLYGON (((-2.37806 51.40636, -2.37878 51...
# 4  MULTIPOLYGON (((-0.46357 52.11582, -0.46430 52...

# %% [markdown]
# The problem is that this city boundaries cannot be applied to this dataset.

# %% [markdown]
# ## 2.4 TTWA EDA (fame_OC)
#
# `TTWA` means "travel to work area"
#
# ref: https://www.ncl.ac.uk/media/wwwnclacuk/curds/files/RR2015-05.pdf
#
# The first 10 TTWAs in the UK can be presented below:

# %%
top_10_ttwa = df.ttwa.value_counts().head(10)
top_10_ttwa = pd.DataFrame(top_10_ttwa).reset_index()
top_10_ttwa.columns = ["ttwa_code","counts"]

df_ttwa = pd.read_csv(PATH + "/Dataset/ttwa.csv")
df_ttwa = pd.merge(top_10_ttwa, df_ttwa[["code","name"]], left_on="ttwa_code",right_on="code")
df_ttwa_10 = df_ttwa[["ttwa_code", "counts", "name"]]
df_ttwa_10.style
# Out:
# <style  type="text/css" >
# </style><table id="T_b807d436_e30f_11eb_b15e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ttwa_code</th>        <th class="col_heading level0 col1" >counts</th>        <th class="col_heading level0 col2" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b807d436_e30f_11eb_b15e_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row0_col0" class="data row0 col0" >E30000234</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row0_col1" class="data row0 col1" >146959</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row0_col2" class="data row0 col2" >London</td>
#             </tr>
#             <tr>
#                         <th id="T_b807d436_e30f_11eb_b15e_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row1_col0" class="data row1 col0" >E30000239</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row1_col1" class="data row1 col1" >21683</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row1_col2" class="data row1 col2" >Manchester</td>
#             </tr>
#             <tr>
#                         <th id="T_b807d436_e30f_11eb_b15e_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row2_col0" class="data row2 col0" >E30000266</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row2_col1" class="data row2 col1" >20224</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row2_col2" class="data row2 col2" >Slough and Heathrow</td>
#             </tr>
#             <tr>
#                         <th id="T_b807d436_e30f_11eb_b15e_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row3_col0" class="data row3 col0" >E30000169</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row3_col1" class="data row3 col1" >11262</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row3_col2" class="data row3 col2" >Birmingham</td>
#             </tr>
#             <tr>
#                         <th id="T_b807d436_e30f_11eb_b15e_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row4_col0" class="data row4 col0" >E30000237</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row4_col1" class="data row4 col1" >10408</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row4_col2" class="data row4 col2" >Luton</td>
#             </tr>
#             <tr>
#                         <th id="T_b807d436_e30f_11eb_b15e_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row5_col0" class="data row5 col0" >E30000175</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row5_col1" class="data row5 col1" >9232</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row5_col2" class="data row5 col2" >Bournemouth</td>
#             </tr>
#             <tr>
#                         <th id="T_b807d436_e30f_11eb_b15e_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row6_col0" class="data row6 col0" >E30000179</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row6_col1" class="data row6 col1" >8368</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row6_col2" class="data row6 col2" >Brighton</td>
#             </tr>
#             <tr>
#                         <th id="T_b807d436_e30f_11eb_b15e_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row7_col0" class="data row7 col0" >E30000186</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row7_col1" class="data row7 col1" >7296</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row7_col2" class="data row7 col2" >Cambridge</td>
#             </tr>
#             <tr>
#                         <th id="T_b807d436_e30f_11eb_b15e_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row8_col0" class="data row8 col0" >E30000180</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row8_col1" class="data row8 col1" >7090</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row8_col2" class="data row8 col2" >Bristol</td>
#             </tr>
#             <tr>
#                         <th id="T_b807d436_e30f_11eb_b15e_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row9_col0" class="data row9 col0" >E30000284</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row9_col1" class="data row9 col1" >6968</td>
#                         <td id="T_b807d436_e30f_11eb_b15e_acde48001122row9_col2" class="data row9 col2" >Warrington and Wigan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Compared to the Largest TTWAs by workplace population, UK, 2011 TTWAs
#
# ![WX20210712-203201@2x.png](attachment:53244432-15aa-442e-9505-708da5b78689.png)

# %% [markdown]
# But it is hard to find the ttwa boundary to do visulisation work. I might consider `Laua` attributes
#
# This **TTWA** EDA value is:
#
# 1. the top 10 tech clusters can be identified like London, Manchester (more details can be found in the [Travel to Work Areas (Mike Coombes and Office for National Statistics, 2015)](https://www.ncl.ac.uk/media/wwwnclacuk/curds/files/RR2015-05.pdf))
#
# 1. Its population of job can be found which is conducive to the **LQs** detecting
#
# The difficulties:
#
# 1. The boundaries dataset is in the[Open Geography portalx](https://geoportal.statistics.gov.uk/datasets/travel-to-work-areas-december-2011-generalised-clipped-boundaries-in-united-kingdom-2/explore?location=54.650000%2C-3.250000%2C5.80), which is hard to get spatial information in Python because its type is `JSON`
#
# 1. The boundaries and work population number is not up-to-date and available in 2021. (I cannot find open data for ttwa in 2020)

# %% [markdown]
# ### 2.4.1 Ttwa spatial info detect
#
# Data source: https://geoportal.statistics.gov.uk/datasets/travel-to-work-areas-december-2011-generalised-clipped-boundaries-in-united-kingdom-2

# %%
import geopandas as gpd
g_ttwa = gpd.read_file(PATH + "/Dataset/Spatial/Travel_to_Work_Areas__December_2011__Generalised_Clipped_Boundaries_in_United_Kingdom.geojson")

# %%
g_ttwa.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3 Mapping the Tech Cluster (Laua & TTWA)
#
# 1. count the frequency of tech firm grouped by `Laua` & `Ttwa`
# 2. import the spatial dataset `local authority boundaries` & `Travel to work area boundaries`
# 3. merge with `1.` and `2.` to visualise the spatial distribution

# %% [markdown]
# ## 3.1 Detect the fame_OC data
#
# drop the rows which contain NA value in the **laua** column

# %%
print(df.shape)
df1 = df.copy()
df1 = df1.dropna(subset=["laua","ttwa"])
print(df1.shape)
# Out:
# (513708, 64)
# (502658, 64)

# %%
# import the laua boundaries
df_laua = pd.read_csv(PATH + "/Dataset/Spatial/Local_Authority_2017.csv")
df_laua.head()
# Out:
#    objectid    lad17cd               lad17nm lad17nmw   bng_e   bng_n  \
# 0         1  E06000001            Hartlepool           447157  531476
# 1         2  E06000002         Middlesbrough           451141  516887
# 2         3  E06000003  Redcar and Cleveland           464359  519597
# 3         4  E06000004      Stockton-on-Tees           444937  518183
# 4         5  E06000005            Darlington           428029  515649
#
#       long        lat  st_areashape  st_lengthshape
# 0 -1.27023  54.676159  9.355951e+07    71707.407523
# 1 -1.21099  54.544670  5.388858e+07    43840.866561
# 2 -1.00611  54.567520  2.448203e+08    97993.391012
# 3 -1.30669  54.556911  2.049622e+08   119581.595543
# 4 -1.56835  54.535351  1.974757e+08   107206.401694

# %%
# import the ttwa boundaries
import geopandas as gpd
df_ttwa = gpd.read_file(PATH + "/Dataset/Spatial/Travel_to_Work_Areas__December_2011__Generalised_Clipped_Boundaries_in_United_Kingdom.geojson")
df_ttwa.head()
# Out:
#    OBJECTID   TTWA11CD                 TTWA11NM   Shape__Area  Shape__Length  \
# 0         1  E30000004                 Barnsley  3.424992e+08  129308.319110
# 1         2  E30000018                 Bradford  3.438902e+08  119605.015955
# 2         3  E30000029                  Halifax  3.639425e+08  105182.259501
# 3         4  E30000039                  Skipton  1.178893e+09  197077.350855
# 4         5  E30000046  Dorchester and Weymouth  7.200201e+08  226091.682220
#
#                                             geometry
# 0  POLYGON ((-1.44681 53.61282, -1.44475 53.61061...
# 1  POLYGON ((-1.94399 53.95619, -1.94161 53.95252...
# 2  POLYGON ((-2.03257 53.81023, -2.03138 53.80902...
# 3  POLYGON ((-2.30733 54.25008, -2.30511 54.24934...
# 4  MULTIPOLYGON (((-2.22501 50.61646, -2.22520 50...

# %% [markdown]
# The top 10 Local Authority can be found in the following list

# %%
# df_laua = pd.read_csv(PATH + "/Dataset/ttwa.csv")
df_laua_10 = pd.DataFrame(df1.laua.value_counts()[:12]).reset_index()
df_laua_10.columns = ["laua_code","count"]

df_laua_10 = pd.merge(df_laua_10, df_laua[["lad17cd","lad17nm"]], left_on="laua_code",right_on="lad17cd")

df_laua_10 = df_laua_10[["laua_code","count","lad17nm"]]
df_laua_10.columns = ["laua_code","count","name"]
df_laua_10.style
# Out:
# <style  type="text/css" >
# </style><table id="T_098db44e_e381_11eb_b15e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >laua_code</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_098db44e_e381_11eb_b15e_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row0_col0" class="data row0 col0" >E09000007</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row0_col1" class="data row0 col1" >15897</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row0_col2" class="data row0 col2" >Camden</td>
#             </tr>
#             <tr>
#                         <th id="T_098db44e_e381_11eb_b15e_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row1_col0" class="data row1 col0" >E09000033</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row1_col1" class="data row1 col1" >12069</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row1_col2" class="data row1 col2" >Westminster</td>
#             </tr>
#             <tr>
#                         <th id="T_098db44e_e381_11eb_b15e_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row2_col0" class="data row2 col0" >E09000012</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row2_col1" class="data row2 col1" >12036</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row2_col2" class="data row2 col2" >Hackney</td>
#             </tr>
#             <tr>
#                         <th id="T_098db44e_e381_11eb_b15e_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row3_col0" class="data row3 col0" >E09000019</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row3_col1" class="data row3 col1" >10271</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row3_col2" class="data row3 col2" >Islington</td>
#             </tr>
#             <tr>
#                         <th id="T_098db44e_e381_11eb_b15e_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row4_col0" class="data row4 col0" >E06000043</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row4_col1" class="data row4 col1" >8026</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row4_col2" class="data row4 col2" >Brighton and Hove</td>
#             </tr>
#             <tr>
#                         <th id="T_098db44e_e381_11eb_b15e_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row5_col0" class="data row5 col0" >E08000025</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row5_col1" class="data row5 col1" >7356</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row5_col2" class="data row5 col2" >Birmingham</td>
#             </tr>
#             <tr>
#                         <th id="T_098db44e_e381_11eb_b15e_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row6_col0" class="data row6 col0" >E09000003</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row6_col1" class="data row6 col1" >7023</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row6_col2" class="data row6 col2" >Barnet</td>
#             </tr>
#             <tr>
#                         <th id="T_098db44e_e381_11eb_b15e_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row7_col0" class="data row7 col0" >E08000003</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row7_col1" class="data row7 col1" >6254</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row7_col2" class="data row7 col2" >Manchester</td>
#             </tr>
#             <tr>
#                         <th id="T_098db44e_e381_11eb_b15e_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row8_col0" class="data row8 col0" >E08000035</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row8_col1" class="data row8 col1" >5899</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row8_col2" class="data row8 col2" >Leeds</td>
#             </tr>
#             <tr>
#                         <th id="T_098db44e_e381_11eb_b15e_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row9_col0" class="data row9 col0" >E09000001</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row9_col1" class="data row9 col1" >5576</td>
#                         <td id="T_098db44e_e381_11eb_b15e_acde48001122row9_col2" class="data row9 col2" >City of London</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - Top 4(the Camden, Westminster, Hackney and Islington clusters) belongs to the London
#
# - Only Brighton and Hove, Birmingham, Manchester and Leeds do **not** belong to London

# %% [markdown]
# The top 10 Travel to Work Area can be found in the following list

# %%
top_10_ttwa = df.ttwa.value_counts().head(10)
top_10_ttwa = pd.DataFrame(top_10_ttwa).reset_index()
top_10_ttwa.columns = ["ttwa_code","counts"]

df_ttwa = pd.read_csv(PATH + "/Dataset/ttwa.csv")
df_ttwa = pd.merge(top_10_ttwa, df_ttwa[["code","name"]], left_on="ttwa_code",right_on="code")
df_ttwa_10 = df_ttwa[["ttwa_code", "counts", "name"]]
df_ttwa_10.style
# Out:
# <style  type="text/css" >
# </style><table id="T_5b551b94_e310_11eb_b15e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ttwa_code</th>        <th class="col_heading level0 col1" >counts</th>        <th class="col_heading level0 col2" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5b551b94_e310_11eb_b15e_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row0_col0" class="data row0 col0" >E30000234</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row0_col1" class="data row0 col1" >146959</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row0_col2" class="data row0 col2" >London</td>
#             </tr>
#             <tr>
#                         <th id="T_5b551b94_e310_11eb_b15e_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row1_col0" class="data row1 col0" >E30000239</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row1_col1" class="data row1 col1" >21683</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row1_col2" class="data row1 col2" >Manchester</td>
#             </tr>
#             <tr>
#                         <th id="T_5b551b94_e310_11eb_b15e_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row2_col0" class="data row2 col0" >E30000266</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row2_col1" class="data row2 col1" >20224</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row2_col2" class="data row2 col2" >Slough and Heathrow</td>
#             </tr>
#             <tr>
#                         <th id="T_5b551b94_e310_11eb_b15e_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row3_col0" class="data row3 col0" >E30000169</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row3_col1" class="data row3 col1" >11262</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row3_col2" class="data row3 col2" >Birmingham</td>
#             </tr>
#             <tr>
#                         <th id="T_5b551b94_e310_11eb_b15e_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row4_col0" class="data row4 col0" >E30000237</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row4_col1" class="data row4 col1" >10408</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row4_col2" class="data row4 col2" >Luton</td>
#             </tr>
#             <tr>
#                         <th id="T_5b551b94_e310_11eb_b15e_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row5_col0" class="data row5 col0" >E30000175</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row5_col1" class="data row5 col1" >9232</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row5_col2" class="data row5 col2" >Bournemouth</td>
#             </tr>
#             <tr>
#                         <th id="T_5b551b94_e310_11eb_b15e_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row6_col0" class="data row6 col0" >E30000179</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row6_col1" class="data row6 col1" >8368</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row6_col2" class="data row6 col2" >Brighton</td>
#             </tr>
#             <tr>
#                         <th id="T_5b551b94_e310_11eb_b15e_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row7_col0" class="data row7 col0" >E30000186</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row7_col1" class="data row7 col1" >7296</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row7_col2" class="data row7 col2" >Cambridge</td>
#             </tr>
#             <tr>
#                         <th id="T_5b551b94_e310_11eb_b15e_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row8_col0" class="data row8 col0" >E30000180</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row8_col1" class="data row8 col1" >7090</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row8_col2" class="data row8 col2" >Bristol</td>
#             </tr>
#             <tr>
#                         <th id="T_5b551b94_e310_11eb_b15e_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row9_col0" class="data row9 col0" >E30000284</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row9_col1" class="data row9 col1" >6968</td>
#                         <td id="T_5b551b94_e310_11eb_b15e_acde48001122row9_col2" class="data row9 col2" >Warrington and Wigan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 3.2 Import the Laua & TTWA spatial info
# This file is `Local_Authority_2019_Boundaries/Local_Authority_Districts_(December_2019)_Boundaries_UK_BFC.shp`

# %%
# read the shape file and plot map

import geopandas as gpd
g_laua = gpd.read_file(PATH + "/Dataset/Spatial/Local_Authority_2019_Boundaries/Local_Authority_Districts_(December_2019)_Boundaries_UK_BFC.shp")
g_ttwa = gpd.read_file(PATH + "/Dataset/Spatial/Travel_to_Work_Areas__December_2011__Generalised_Clipped_Boundaries_in_United_Kingdom.geojson")
# print(g_laua)

# %%
g_laua.plot()
g_ttwa.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3.3 Merge the spatial and info

# %% [markdown]
# get the laua and frequency list and transform into the frequency

# %%
df_laua_freq = pd.DataFrame(df1.laua.value_counts()).reset_index()
df_laua_freq.columns = ["laua_code","count"]
df_laua_freq.head()
# Out:
#    laua_code  count
# 0  E09000007  15897
# 1  E09000033  12069
# 2  E09000012  12036
# 3  E09000019  10271
# 4  E06000058   9437

# %% [markdown]
# get the ttwa and frequency list and transform into the frequency

# %%
df_ttwa_freq = pd.DataFrame(df1.ttwa.value_counts()).reset_index()
df_ttwa_freq.columns = ["ttwa_code","count"]
df_ttwa_freq.head()
# Out:
#    ttwa_code   count
# 0  E30000234  146959
# 1  E30000239   21683
# 2  E30000266   20224
# 3  E30000169   11262
# 4  E30000237   10408

# %% [markdown]
# 1. merge the `df_laua_freq` and `g_laua`
# 1. merge the `df_ttwa_freq` and `g_ttwa`

# %%
df_laua_mg = pd.merge(g_laua, df_laua_freq,left_on='lad19cd',right_on='laua_code',how='inner').reset_index()
df_ttwa_mg = pd.merge(g_ttwa, df_ttwa_freq, left_on='TTWA11CD', right_on='ttwa_code',how='inner').reset_index()
df_laua_mg.plot()
df_ttwa_mg.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# cmap settings ref: https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# ## 3.4 Mapping the Freuqency

# %%
import pysal as ps
import numpy as np
import pandas as pd
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt

tfont = {'fontname':'DejaVu Sans', 'horizontalalignment':'left'}
f1_laua = plt.figure()
f1_laua.set_size_inches(20,20)

ax1 = f1_laua.add_subplot()
df_laua_mg.plot(column='count', legend=True, cmap='YlGn', ax=ax1)
# df_laua_mg.plot(column='count', legend=True, cmap='plasma',figsize=(180,60),ax=ax1)

f1_laua.subplots_adjust(top=0.95)
# f1.suptitle(f"Frequency Distribution of tech firms cluster by Local Authorities", x=0.025, size=24, **tfont)
f1_laua.suptitle(f"Spatial Distribution of the number of tech firms cluster in UK Local Authorities", x=0.25, size=24, **tfont)
f1_laua.savefig(PATH + '/Img/Frequency_Distribution_of_tech_firms_cluster_by_LAUA.png', dpi=300)

# %%
df_ttwa_mg
# Out:
#      index  OBJECTID   TTWA11CD                 TTWA11NM   Shape__Area  \
# 0        0         1  E30000004                 Barnsley  3.424992e+08
# 1        1         2  E30000018                 Bradford  3.438902e+08
# 2        2         3  E30000029                  Halifax  3.639425e+08
# 3        3         4  E30000039                  Skipton  1.178893e+09
# 4        4         5  E30000046  Dorchester and Weymouth  7.200201e+08
# ..     ...       ...        ...                      ...           ...
# 223    223       224  W22000030  Pwllheli and Porthmadog  6.734859e+08
# 224    224       225  W22000031                     Rhyl  1.219876e+09
# 225    225       226  W22000032                  Swansea  1.002925e+09
# 226    226       227  W22000033      Tywyn and Dolgellau  1.419986e+09
# 227    227       228  W22000034                  Wrexham  5.103039e+08
#
#      Shape__Length                                           geometry  \
# 0    129308.319110  POLYGON ((-1.44681 53.61282, -1.44475 53.61061...
# 1    119605.015955  POLYGON ((-1.94399 53.95619, -1.94161 53.95252...
# 2    105182.259501  POLYGON ((-2.03257 53.81023, -2.03138 53.80902...
# 3    197077.350855  POLYGON ((-2.30733 54.25008, -2.30511 54.24934...
# 4    226091.682220  MULTIPOLYGON (((-2.22501 50.61646, -2.22520 50...
# ..             ...                                                ...
# 223  255493.843537  MULTIPOLYGON (((-4.80252 52.75667, -4.80423 52...
# 224  275509.758780  MULTIPOLYGON (((-3.45998 53.28200, -3.46014 53...
# 225  409732.315759  MULTIPOLYGON (((-3.76057 51.53667, -3.76110 51...
# 226  291174.323726  MULTIPOLYGON (((-3.92305 52.75456, -3.92483 52...
# 227  162452.205500  POLYGON ((-3.12262 53.15796, -3.11578 53.15503...
#
#      ttwa_code  count
# 0    E30000004    940
# 1    E30000018   2258
# 2    E30000029   1164
# 3    E30000039    267
# 4    E30000046    708
# ..         ...    ...
# 223  W22000030     98
# 224  W22000031    482
# 225  W22000032   1293
# 226  W22000033     51
# 227  W22000034    507
#
# [228 rows x 9 columns]

# %%
# map the ttwa and frequency of tech clusters
tfont = {'fontname':'DejaVu Sans', 'horizontalalignment':'left'}
f1_ttwa = plt.figure()
f1_ttwa.set_size_inches(20,20)

ax1 = f1_ttwa.add_subplot()
df_ttwa_mg.plot(column='count', legend=True, cmap='YlGn', ax=ax1)
# df_laua_mg.plot(column='count', legend=True, cmap='plasma',figsize=(180,60),ax=ax1)

f1_ttwa.subplots_adjust(top=0.95)
# f1.suptitle(f"Frequency Distribution of tech firms cluster by Local Authorities", x=0.025, size=24, **tfont)
f1_ttwa.suptitle(f"Spatial Distribution of the number of tech firms cluster in UK Travel to Work Area", x=0.25, size=24, **tfont)
f1_ttwa.savefig(PATH+'/Img/Frequency_Distribution_of_tech_firms_cluster_by_TTWA.png', dpi=300)

# %% [markdown]
# For create a high contrast, making the TTWA (less than top 10) count 0.
#
# We need `df_ttwa_10` & `df_ttwa_mg` to make a better visualisation version

# %%
df_ttwa_10.head()
# Out:
#    ttwa_code  counts                 name
# 0  E30000234  146959               London
# 1  E30000239   21683           Manchester
# 2  E30000266   20224  Slough and Heathrow
# 3  E30000169   11262           Birmingham
# 4  E30000237   10408                Luton

# %%
df_ttwa_mg.head()
# Out:
#    index  OBJECTID   TTWA11CD                 TTWA11NM   Shape__Area  \
# 0      0         1  E30000004                 Barnsley  3.424992e+08
# 1      1         2  E30000018                 Bradford  3.438902e+08
# 2      2         3  E30000029                  Halifax  3.639425e+08
# 3      3         4  E30000039                  Skipton  1.178893e+09
# 4      4         5  E30000046  Dorchester and Weymouth  7.200201e+08
#
#    Shape__Length                                           geometry  \
# 0  129308.319110  POLYGON ((-1.44681 53.61282, -1.44475 53.61061...
# 1  119605.015955  POLYGON ((-1.94399 53.95619, -1.94161 53.95252...
# 2  105182.259501  POLYGON ((-2.03257 53.81023, -2.03138 53.80902...
# 3  197077.350855  POLYGON ((-2.30733 54.25008, -2.30511 54.24934...
# 4  226091.682220  MULTIPOLYGON (((-2.22501 50.61646, -2.22520 50...
#
#    ttwa_code  count
# 0  E30000004      0
# 1  E30000018      0
# 2  E30000029      0
# 3  E30000039      0
# 4  E30000046      0

# %%
df_ttwa_mg_for_viz = df_ttwa_mg.copy()
df_ttwa_mg_for_viz.loc[~df_ttwa_mg_for_viz["TTWA11CD"].isin(df_ttwa_10.ttwa_code.to_list()),"count"]=-100000
df_ttwa_mg_for_viz
# Out:
#      index  OBJECTID   TTWA11CD                 TTWA11NM   Shape__Area  \
# 0        0         1  E30000004                 Barnsley  3.424992e+08
# 1        1         2  E30000018                 Bradford  3.438902e+08
# 2        2         3  E30000029                  Halifax  3.639425e+08
# 3        3         4  E30000039                  Skipton  1.178893e+09
# 4        4         5  E30000046  Dorchester and Weymouth  7.200201e+08
# ..     ...       ...        ...                      ...           ...
# 223    223       224  W22000030  Pwllheli and Porthmadog  6.734859e+08
# 224    224       225  W22000031                     Rhyl  1.219876e+09
# 225    225       226  W22000032                  Swansea  1.002925e+09
# 226    226       227  W22000033      Tywyn and Dolgellau  1.419986e+09
# 227    227       228  W22000034                  Wrexham  5.103039e+08
#
#      Shape__Length                                           geometry  \
# 0    129308.319110  POLYGON ((-1.44681 53.61282, -1.44475 53.61061...
# 1    119605.015955  POLYGON ((-1.94399 53.95619, -1.94161 53.95252...
# 2    105182.259501  POLYGON ((-2.03257 53.81023, -2.03138 53.80902...
# 3    197077.350855  POLYGON ((-2.30733 54.25008, -2.30511 54.24934...
# 4    226091.682220  MULTIPOLYGON (((-2.22501 50.61646, -2.22520 50...
# ..             ...                                                ...
# 223  255493.843537  MULTIPOLYGON (((-4.80252 52.75667, -4.80423 52...
# 224  275509.758780  MULTIPOLYGON (((-3.45998 53.28200, -3.46014 53...
# 225  409732.315759  MULTIPOLYGON (((-3.76057 51.53667, -3.76110 51...
# 226  291174.323726  MULTIPOLYGON (((-3.92305 52.75456, -3.92483 52...
# 227  162452.205500  POLYGON ((-3.12262 53.15796, -3.11578 53.15503...
#
#      ttwa_code   count
# 0    E30000004 -100000
# 1    E30000018 -100000
# 2    E30000029 -100000
# 3    E30000039 -100000
# 4    E30000046 -100000
# ..         ...     ...
# 223  W22000030 -100000
# 224  W22000031 -100000
# 225  W22000032 -100000
# 226  W22000033 -100000
# 227  W22000034 -100000
#
# [228 rows x 9 columns]

# %% [markdown]
# note: the `loc` is a "inplace = True" method, you dont need to write `df = df.loc[]` just `df.loc[] = ..`

# %%
# map the ttwa and frequency of tech clusters again!!
tfont = {'fontname':'DejaVu Sans', 'horizontalalignment':'left'}
f1_ttwa = plt.figure()
f1_ttwa.set_size_inches(20,20)

ax1 = f1_ttwa.add_subplot()
cmap_set = "tab20b"
df_ttwa_mg_for_viz.plot(column='count', legend=True, cmap=cmap_set, ax=ax1)
# coolwarm
# winter
# tab20b
# tab20c
# df_laua_mg.plot(column='count', legend=True, cmap='plasma',figsize=(180,60),ax=ax1)

f1_ttwa.subplots_adjust(top=0.95)
# f1.suptitle(f"Frequency Distribution of tech firms cluster by Local Authorities", x=0.025, size=24, **tfont)
f1_ttwa.suptitle(f"Spatial Distribution of the number of tech firms cluster in UK Travel to Work Area", x=0.25, size=24, **tfont)
f1_ttwa.savefig(PATH+'/Img/Frequency_Distribution_of_tech_firms_cluster_by_TTWA' + '_' + cmap_set + '.png', dpi=300)

# %% [markdown]
# ## 3.5 Plot the Bar Chart

# %%
df_laua_10.style
# Out:
# <style  type="text/css" >
# </style><table id="T_ec725118_d2a4_11eb_a8f2_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >laua_code</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ec725118_d2a4_11eb_a8f2_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row0_col0" class="data row0 col0" >E09000007</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row0_col1" class="data row0 col1" >15897</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row0_col2" class="data row0 col2" >Camden</td>
#             </tr>
#             <tr>
#                         <th id="T_ec725118_d2a4_11eb_a8f2_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row1_col0" class="data row1 col0" >E09000033</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row1_col1" class="data row1 col1" >12069</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row1_col2" class="data row1 col2" >Westminster</td>
#             </tr>
#             <tr>
#                         <th id="T_ec725118_d2a4_11eb_a8f2_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row2_col0" class="data row2 col0" >E09000012</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row2_col1" class="data row2 col1" >12036</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row2_col2" class="data row2 col2" >Hackney</td>
#             </tr>
#             <tr>
#                         <th id="T_ec725118_d2a4_11eb_a8f2_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row3_col0" class="data row3 col0" >E09000019</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row3_col1" class="data row3 col1" >10271</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row3_col2" class="data row3 col2" >Islington</td>
#             </tr>
#             <tr>
#                         <th id="T_ec725118_d2a4_11eb_a8f2_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row4_col0" class="data row4 col0" >E06000043</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row4_col1" class="data row4 col1" >8026</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row4_col2" class="data row4 col2" >Brighton and Hove</td>
#             </tr>
#             <tr>
#                         <th id="T_ec725118_d2a4_11eb_a8f2_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row5_col0" class="data row5 col0" >E08000025</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row5_col1" class="data row5 col1" >7356</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row5_col2" class="data row5 col2" >Birmingham</td>
#             </tr>
#             <tr>
#                         <th id="T_ec725118_d2a4_11eb_a8f2_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row6_col0" class="data row6 col0" >E09000003</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row6_col1" class="data row6 col1" >7023</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row6_col2" class="data row6 col2" >Barnet</td>
#             </tr>
#             <tr>
#                         <th id="T_ec725118_d2a4_11eb_a8f2_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row7_col0" class="data row7 col0" >E08000003</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row7_col1" class="data row7 col1" >6254</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row7_col2" class="data row7 col2" >Manchester</td>
#             </tr>
#             <tr>
#                         <th id="T_ec725118_d2a4_11eb_a8f2_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row8_col0" class="data row8 col0" >E08000035</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row8_col1" class="data row8 col1" >5899</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row8_col2" class="data row8 col2" >Leeds</td>
#             </tr>
#             <tr>
#                         <th id="T_ec725118_d2a4_11eb_a8f2_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row9_col0" class="data row9 col0" >E09000001</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row9_col1" class="data row9 col1" >5576</td>
#                         <td id="T_ec725118_d2a4_11eb_a8f2_acde48001122row9_col2" class="data row9 col2" >City of London</td>
#             </tr>
#     </tbody></table>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f2_laua, ax2 = plt.subplots(figsize=(15,6))

# Load the example car crash dataset
# crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="count", y="name", data=df_laua_10, color="b")

# Add a legend and informative axis label
# ax.legend(ncol=2, loc="lower right", frameon=True)
ax2.set(xlim=(0, 16050), ylabel="", xlabel="the number of technology companies")
ax2.set_title("Top 10 local authorities with the largest number of technology companies in the UK",fontsize = 24)
# sns.despine(left=True, bottom=True)
f2_laua.savefig(PATH + "/Img/The_Top_10_Number_of_Tech_Firms_laua.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f2_ttwa, ax2 = plt.subplots(figsize=(15,6))

# Load the example car crash dataset
# crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="counts", y="name", data=df_ttwa_10, color="b")

# Add a legend and informative axis label
# ax.legend(ncol=2, loc="lower right", frameon=True)
ax2.set(xlim=(0, 150000), ylabel="", xlabel="the number of technology companies")
ax2.set_title("Top 10 Travel to Work Area with the largest number of technology companies in the UK",fontsize = 24)
# sns.despine(left=True, bottom=True)
f2_ttwa.savefig(PATH + "/Img/The_Top_10_Number_of_Tech_Firms_ttwa.png")

# %% [markdown]
# # 4 Explore the Movers
#
# For `fame_OC`
# 1. keep the same name before and after movement
# 2. change the name before and after movement

# %%
df2 = df.copy()
firm_name_freq = pd.DataFrame(df2.normalised_name.value_counts()).reset_index()
firm_name_freq.columns = ["firm_name","count"]

# firm's name re-appears
firm_name_re = firm_name_freq[firm_name_freq["count"]>1]
firm_name_re.style
# Out:
# <style  type="text/css" >
# </style><table id="T_3ec08b7c_d301_11eb_a8f2_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >firm_name</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row0_col0" class="data row0 col0" >plexus holdings plc</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row0_col1" class="data row0 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row1_col0" class="data row1 col0" >rhythmone plc</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row1_col1" class="data row1 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row2_col0" class="data row2 col0" >mcguirk industries limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row2_col1" class="data row2 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row3_col0" class="data row3 col0" >create limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row3_col1" class="data row3 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row4_col0" class="data row4 col0" >solutions design limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row4_col1" class="data row4 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row5_col0" class="data row5 col0" >synthesizedesign limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row5_col1" class="data row5 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row6_col0" class="data row6 col0" >multiconnect limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row6_col1" class="data row6 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row7_col0" class="data row7 col0" >ja richardson engineering limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row7_col1" class="data row7 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row8_col0" class="data row8 col0" >entertainment international limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row8_col1" class="data row8 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row9_col0" class="data row9 col0" >globex corporation limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row9_col1" class="data row9 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row10_col0" class="data row10 col0" >bloody surgery limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row10_col1" class="data row10 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row11_col0" class="data row11 col0" >dwm media limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row11_col1" class="data row11 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row12_col0" class="data row12 col0" >jc film limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row12_col1" class="data row12 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row13_col0" class="data row13 col0" >sar uk limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row13_col1" class="data row13 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row14_col0" class="data row14 col0" >kcom group plc</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row14_col1" class="data row14 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row15_col0" class="data row15 col0" >jkl tribe limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row15_col1" class="data row15 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row16_col0" class="data row16 col0" >bucks cbt plus limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row16_col1" class="data row16 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row17_col0" class="data row17 col0" >conversion company limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row17_col1" class="data row17 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec08b7c_d301_11eb_a8f2_acde48001122level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row18_col0" class="data row18 col0" >proact it uk limited</td>
#                         <td id="T_3ec08b7c_d301_11eb_a8f2_acde48001122row18_col1" class="data row18 col1" >2</td>
#             </tr>
#             <t

# %% [markdown]
# In this case, I can detect the **41** companies that might move
#
# Then back to the `fame_OC` and filter these possible movers

# %%
df_fame_movers = df.copy()
df_fame_movers = df_fame_movers[df_fame_movers.normalised_name.isin(firm_name_re.firm_name.to_list())]
# df_fame_movers.to_csv(PATH + "/df_fame_OC_movers.csv")

# %%
# detect which one has different postcode in the same normalised name
df_movers = pd.DataFrame(df_fame_movers.groupby("normalised_name")["postcode"].nunique()).reset_index()
# more than 2 distinct postcodes mean these tech firms may move
df_movers = df_movers[df_movers["postcode"]>=2]
# Out:
#                         normalised_name  postcode
# 0            access it resource limited         1
# 1                 acm transport limited         1
# 2                       agility limited         2
# 3                      amd tech limited         2
# 4                        anlex8 limited         1
# 5                bloody surgery limited         1
# 6                bucks cbt plus limited         1
# 7             cliste consulting limited         1
# 8            conversion company limited         2
# 9                        create limited         2
# 10                       ctrl z limited         2
# 11                    dwm media limited         1
# 12  entertainment international limited         2
# 13                   eye clinic limited         2
# 14           future corporation limited         2
# 15           globex corporation limited         2
# 16            gopher it support limited         1
# 17              grace and grace limited         2
# 18                    hit reset limited         2
# 19                         hive limited         2
# 20    ja richardson engineering limited         1
# 21                      jc film limited         2
# 22                  jd software limited         2
# 23                    jkl tribe limited         1
# 24                       kcom group plc         1
# 25                              limited         2
# 26              mak corporation limited         2
# 27           mcguirk industries limited         1
# 28                   mind music limited         2
# 29                 multiconnect limited         1
# 30              nmr geosciences limited         1
# 31                  plexus holdings plc         1
# 32                 proact it uk limited         1
# 33       quality care solutions limited         2
# 34             ready player one limited         1
# 35                      red red limited         2
# 36                        rhythmone plc         1
# 37                       sar uk limited         2
# 38             solutions design limited         2
# 39              sri corporation limited         2
# 40             synthesizedesign limited         1
# 41                  we unicorns limited         2

# %%
# export a list that tech firm have different postcode while they have the same names
df_movers_1 = df_fame_movers[df_fame_movers["normalised_name"].isin(df_movers["normalised_name"].to_list())]
possible_tech_movers = df_movers_1[["registered_number","incorporation_date","dissolution_date","normalised_name","postcode"]].sort_values(by="normalised_name")
possible_tech_movers
# Out:
#        registered_number incorporation_date dissolution_date  \
# 164178           3060979         1995-05-24              NaN
# 144252          07418654         2010-10-25              NaN
# 279459          11632107         2018-10-19              NaN
# 182708          06250619         2007-05-17              NaN
# 228143          08424152         2013-02-28              NaN
# 512012           1981640         1986-01-23              NaN
# 157297          SC583384         2017-12-07              NaN
# 285768           7460781         2010-12-06              NaN
# 20379           11059998         2017-11-13              NaN
# 469818          05608171         2005-11-01              NaN
# 213430          11634444         2018-10-22              NaN
# 323343          11143790         2018-01-10              NaN
# 12019            8070874         2012-05-16              NaN
# 211689          06219671         2007-04-19              NaN
# 140510           7744742         2011-08-18              NaN
# 39534            5631136         2005-11-21              NaN
# 271030          04397427         2002-03-18              NaN
# 19904           09552070         2015-04-21              NaN
# 387395          11065921         2017-11-15              NaN
# 241453          11412829         2018-06-13              NaN
# 47123            8546782         2013-05-28              NaN
# 224545           6598405         2008-05-20              NaN
# 242014           3937810         2000-03-01              NaN
# 511527          10797308         2017-06-01              NaN
# 291684          10589202         2017-01-30              NaN
# 143676          11613438         2018-10-09              NaN
# 424940           9549356         2015-04-19              NaN
# 72656           04405957         2002-03-28              NaN
# 133614          11306057         2018-04-12              NaN
# 326148          10219186         2016-06-07              NaN
# 8204             7998847         2012-03-20              NaN
# 39799           10674075         2017-03-16              NaN
# 323418           9252531         2014-10-07              NaN
# 153204          09331890         2014-11-28              NaN
# 192884           9989675         2016-02-05              NaN
# 407150           7745467         2011-08-18              NaN
# 33981           11438196         2018-06-28              NaN
# 215822          11233132         2018-03-05              NaN
# 332492           6329371         2007-07-31              NaN
# 268281           8922191         2014-03-04              NaN
# 180039          05549948         2005-08-31              NaN
# 494527          11567756         2018-09-13              NaN
# 368604           8417509         2013-02-25              NaN
# 398016           8817694         2013-12-17              NaN
# 151594          11487977         2018-07-27              NaN
# 491599           9732240         2015-08-13              NaN
#
#                             normalised_name postcode
# 164178                      agility limited   EN49HN
# 144252                      agility limited  EC1V2NX
# 279459                     amd tech limited   N156RH
# 182708                     amd tech limited   GL53PN
# 228143           conversion company limited   KT70RY
# 512012           conversion company limited  YO211QL
# 157297                       create limited  EH107DU
# 285768                       create limited    N17GU
# 20379                        ctrl z limited  BA113EE
# 469818                       ctrl z limited   W1T6AD
# 213430  entertainment international limited  IG110GH
# 323343  entertainment international limited   NW51EN
# 12019                    eye clinic limited   B288EZ
# 211689                   eye clinic limited   HU53TS
# 140510           future corporation limited    E83DL
# 39534            future corporation limited   BL26RT
# 271030           globex corporation limited  MK428TU
# 19904            globex corporation limited   B976HR
# 387395              grace and grace limited   SE64EJ
# 241453              grace and grace limited  LL116UG
# 47123                     hit reset limited   BN16AF
# 224545                    hit reset limited  KT168PD
# 242014                         hive limited  LL181RF
# 511527                         hive limited  YO126HT
# 291684                      jc film limited    N32JU
# 143676                      jc film limited  EC1R0DU
# 424940                  jd software limited  SW152BF
# 72656                   jd software limited  CB249AD
# 133614                              limited   E162DQ
# 326148                              limited   NW99NL
# 8204                mak corporation limited   B112AA
# 39799               mak corporation limited   BL35AZ
# 323418                   mind music limited   NW51UA
# 153204                   mind music limited  EC2R6AY
# 192884       quality care solutions limited   HA12SP
# 407150       quality care solutions limited   SN33AJ
# 33981                       red red limited  BH149NY
# 215822                      red red limited   IG45HQ
# 332492                       sar uk limited   OX46NG
# 268281                       sar uk limited   MK11SW
# 180039             solutions design limited  GL170PZ
# 494527             solutions design limited  WC2H9JQ
# 368604              sri corporation limited   S117AQ
# 398016              sri corporation limited   SL11UA
# 151594                  we unicorns limited  EC2A4NE
# 491599                  we unicorns limited  WC2H7LA
